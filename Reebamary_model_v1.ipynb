# %%
import numpy as np
from sklearn import neighbors
from sklearn.model_selection import train_test_split
import pandas as pd

# %%
#data cleaning
Breast_cancer=pd.read_csv('Breast_cancerdata.csv')
Breast_cancer.drop(['id'], 1, inplace=True)
Breast_cancer.drop(['Unnamed: 32'], 1, inplace=True)
Breast_cancer.replace(np.nan, 0)
Breast_cancer.replace(np.NaN, 0)
Breast_cancer.head()
# Out:
# C:\Users\reeba\AppData\Local\Temp\ipykernel_15056\2590944374.py:3: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only.
#   Breast_cancer.drop(['id'], 1, inplace=True)
# C:\Users\reeba\AppData\Local\Temp\ipykernel_15056\2590944374.py:4: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only.
#   Breast_cancer.drop(['Unnamed: 32'], 1, inplace=True)
#   diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0         M        17.99         10.38          122.80     1001.0
# 1         M        20.57         17.77          132.90     1326.0
# 2         M        19.69         21.25          130.00     1203.0
# 3         M        11.42         20.38           77.58      386.1
# 4         M        20.29         14.34          135.10     1297.0
#
#    smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# ...

# %%
#Define x and y variable
x = Breast_cancer.drop('diagnosis',axis=1).to_numpy()
y = Breast_cancer['diagnosis'].to_numpy()

# Create Train and Test Datasets
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.20,stratify=y,random_state=100)

print(x_train)
# Out:
# [[1.227e+01 1.792e+01 7.841e+01 ... 9.532e-02 3.455e-01 6.896e-02]
#  [1.660e+01 2.808e+01 1.083e+02 ... 1.418e-01 2.218e-01 7.820e-02]
#  [1.145e+01 2.097e+01 7.381e+01 ... 6.127e-02 2.762e-01 8.851e-02]
#  ...
#  [1.375e+01 2.377e+01 8.854e+01 ... 6.106e-02 2.663e-01 6.321e-02]
#  [1.246e+01 1.283e+01 7.883e+01 ... 2.680e-02 2.280e-01 7.028e-02]
#  [1.445e+01 2.022e+01 9.449e+01 ... 1.838e-01 4.753e-01 1.013e-01]]

# %%
#Model building using KNN
clf = neighbors.KNeighborsClassifier()
clf.fit(x_train, y_train)

# test accuracy of the classifier
accuracy = clf.score(x_test, y_test)
print('Accuracy:', accuracy)
# Out:
# Accuracy: 0.8947368421052632
